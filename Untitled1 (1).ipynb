# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread('/content/i1.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()

# %%
r_thresh = 200

# %%
image.shape
# Out:
# (512, 512, 3)

# %%
red_color = image[:, :, 0] > r_thresh
image[np.where(red_color)] = [0, 0, 0]

# %%
plt.imshow(image)
plt.show()
